# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('val.csv',sep='\t')
print(df['Training Loss'].to_list())
print(df['Validation Loss'].to_list())
print(df['Acc'].to_list())
# Out:
# [0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]
# [0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 1.116158]
# [0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

# %%
weighted_train_loss1=[0.5647, 0.4493, 0.2963, 0.343, 0.2907, 0.2787, 0.2617, 0.2416, 0.2186, 0.1901, 
                      0.229, 0.2455, 0.1648, 0.1927, 0.1658]

weighted_train_loss2=[0.5311, 0.3814, 0.2795, 0.3023, 0.2534, 0.2231, 0.1994, 0.1681,
                      0.1882, 0.1458, 0.1631, 0.1496, 0.1323, 0.1421, 0.1268]

weighted_train_loss3=[0.4175, 0.2984, 0.2228, 0.2252, 0.1962, 0.1804, 0.1611, 0.1371, 0.1402, 0.1132, 
                      0.1063, 0.1181, 0.0926, 0.1006, 0.0879]

weighted_train_loss4=[0.3433, 0.2507, 0.1932, 0.197, 0.1709, 0.1549, 0.14, 0.1221, 0.1169, 0.0995, 
                      0.0858, 0.0911, 0.0712, 0.0864, 0.0807]

weighted_train_loss5=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043,
                      0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

# %%
train_loss1=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043, 
             0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

train_loss2=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043, 
             0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

train_loss3=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043, 
             0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

train_loss4=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043, 
             0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

train_loss5=[0.2923, 0.2188, 0.1765, 0.1764, 0.1453, 0.1298, 0.1233, 0.1058, 0.1043, 
             0.09, 0.0734, 0.0757, 0.0679, 0.0692, 0.0661]

# %%
plt.plot(weighted_train_loss1, label='Fraction of Positive class samples=0.1')
plt.plot(weighted_train_loss2, label='Fraction of Positive class samples=0.25')
plt.plot(weighted_train_loss3, label='Fraction of Positive class samples=0.5')
plt.plot(weighted_train_loss4, label='Fraction of Positive class samples=0.75')
plt.plot(weighted_train_loss5, label='Fraction of Positive class samples=1')
plt.legend()

# %%
weighted_val_loss1=[0.509555, 0.8715450000000001, 0.6837949999999999, 1.246229, 0.998677, 1.2319309999999999, 
                    0.829916, 1.457525, 1.351178, 1.873821, 2.501679, 1.826048, 2.551577, 2.400285, 2.3670080000000002]

weighted_val_loss2=[0.63359, 0.832522, 0.5768300000000001, 1.099218, 1.181514, 1.408228, 0.8103090000000001, 
                    1.959038, 1.3910799999999999, 1.4269209999999999, 2.083308, 1.886785, 2.66847, 2.352047, 2.324096]

weighted_val_loss3=[0.917208, 0.872383, 0.629225, 1.447408, 0.9708469999999999, 1.305283, 0.9497120000000001,
                    2.0285900000000003, 1.290353, 1.288357, 1.804832, 1.6760560000000002, 2.099899, 2.167818, 
                    2.070665]

weighted_val_loss4=[0.7202, 0.9930530000000001, 0.5818810000000001, 1.244653, 1.097437, 1.245999, 0.8875049999999999,
      0.725917, 0.7477060000000001, 0.71445, 0.722477, 0.722477, 0.707569, 0.7178899999999999]

acc2=[0.588303, 0.635321, 0.701835, 0.701835, 0.6834859999999999, 0.672018, 0.724771, 0.678899,
      0.725917, 0.7477060000000001, 0.71445, 0.722477, 0.722477, 0.707569, 0.7178899999999999]

acc3=[0.588303, 0.635321, 0.701835, 0.701835, 0.6834859999999999, 0.672018, 0.724771, 0.678899,
      0.725917, 0.7477060000000001, 0.71445, 0.722477, 0.722477, 0.707569, 0.7178899999999999]

acc4=[0.588303, 0.635321, 0.701835, 0.701835, 0.6834859999999999, 0.672018, 0.724771, 0.678899,
      0.725917, 0.7477060000000001, 0.71445, 0.722477, 0.722477, 0.707569, 0.7178899999999999]

acc5=[0.588303, 0.635321, 0.701835, 0.701835, 0.6834859999999999, 0.672018, 0.724771, 0.678899,
      0.725917, 0.7477060000000001, 0.71445, 0.722477, 0.722477, 0.707569, 0.7178899999999999]

# %%
plt.plot(weighted_acc1, label='Fraction of Positive class samples=0.1')
plt.plot(weighted_acc2, label='Fraction of Positive class samples=0.25')
plt.plot(weighted_acc3, label='Fraction of Positive class samples=0.5')
plt.plot(weighted_acc4, label='Fraction of Positive class samples=0.75')
plt.plot(weighted_acc5, label='Fraction of Positive class samples=1')
plt.legend()

# %%
weighted_accs = [weighted_acc1,weighted_acc2,weighted_acc3,weighted_acc4,weighted_acc5]
accs = [acc1,acc2,acc3,acc4,acc5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_accs[i], label='Weighted')
    axes[i].plot(accs[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
weighted_val_loss = [weighted_val_loss1,weighted_val_loss2,weighted_val_loss3,weighted_val_loss4,weighted_val_loss5]
val_loss = [val_loss1,val_loss2,val_loss3,val_loss4,val_loss5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_val_loss[i], label='Weighted')
    axes[i].plot(val_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)

plt.show()

# %%
weighted_train_loss = [weighted_train_loss1,weighted_train_loss2,weighted_train_loss3,weighted_train_loss4,weighted_train_loss5]
train_loss = [train_loss1,train_loss2,train_loss3,train_loss4,train_loss5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]

fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_train_loss[i], label='Weighted')
    axes[i].plot(train_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))

ax[0].plot(weighted_acc1, label='Fraction of Positive class samples=0.1')
ax[0].plot(weighted_acc2, label='Fraction of Positive class samples=0.25')
ax[0].plot(weighted_acc3, label='Fraction of Positive class samples=0.5')
ax[0].plot(weighted_acc4, label='Fraction of Positive class samples=0.75')
ax[0].plot(weighted_acc5, label='Fraction of Positive class samples=1')
ax[0].plot(acc5, label='Non Weighted')
ax[0].set_title("Weighted")
ax[0].legend()


ax[1].plot(acc1, label='Fraction of Positive class samples=0.1')
ax[1].plot(acc2, label='Fraction of Positive class samples=0.25')
ax[1].plot(acc3, label='Fraction of Positive class samples=0.5')
ax[1].plot(acc4, label='Fraction of Positive class samples=0.75')
ax[1].plot(acc5, label='Fraction of Positive class samples=1')
ax[1].set_title("Non Weighted")
ax[1].legend()

plt.show()
