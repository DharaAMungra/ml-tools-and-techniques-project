# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('val.csv',sep='\t')
print(df['Training Loss'].to_list())
print(df['Validation Loss'].to_list())
print(df['Acc'].to_list())
# Out:
# [0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]
# [0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 1.116158]
# [0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

# %%
weighted_train_loss1=[0.2904, 0.3006, 0.1602, 0.1755, 0.0531, 0.063, 0.056, 0.008, 0.0291, 
                      0.0576, 0.0001, 0.0049, 0.0297, 0.0001, 0.0021]

weighted_train_loss2=[0.2576, 0.213, 0.1217, 0.0989, 0.0636, 0.0744, 0.04, 0.0199, 0.0178, 0.0008, 0.0167, 
                      0.0071, 0.0044, 0.0001, 0.0169]

weighted_train_loss3=[0.2036, 0.151, 0.0814, 0.0658, 0.0578, 0.0335, 0.0298, 0.0088, 0.0148,
                      0.007, 0.0073, 0.0129, 0.0065, 0.0, 0.0002]

weighted_train_loss4=[0.1693, 0.1222, 0.0724, 0.0524, 0.0349, 0.0339, 0.0178, 0.0082, 0.0066, 0.0051, 0.0067, 
                      0.0039, 0.006, 0.0, 0.0016]

weighted_train_loss5=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 0.0084, 0.0046, 
                      0.0091, 0.0138, 0.0132, 0.0, 0.0081]

# %%
train_loss1=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 
             0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]

train_loss2=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 
             0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]

train_loss3=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 
             0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]

train_loss4=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 
             0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]

train_loss5=[0.1448, 0.1035, 0.062, 0.0475, 0.0409, 0.0315, 0.0128, 0.0131, 
             0.0084, 0.0046, 0.0091, 0.0138, 0.0132, 0.0, 0.0081]

# %%
plt.plot(weighted_train_loss1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_train_loss2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_train_loss3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_train_loss4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_train_loss5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_val_loss1=[0.47587399999999996, 0.6524260000000001, 0.558211, 0.803028, 0.553898, 1.102687, 0.921723,
                    1.141868, 1.21232, 1.545506, 1.521301, 1.6857099999999998, 1.316842, 1.3811209999999998, 1.585518]

weighted_val_loss2=[0.506093, 0.755722, 0.6832, 0.7729689999999999, 0.642849, 1.013363, 0.670802, 1.194721, 
                    1.503488, 1.7527970000000002, 1.565612, 1.524449, 1.6739080000000002, 1.4484549999999998, 1.62411]

weighted_val_loss3=[0.478825, 0.76984, 0.605175, 0.7026789999999999, 0.512441, 0.918392, 0.770221, 0.931873, 
                    1.2296209999999999, 1.3032059999999999, 1.208754, 1.181653, 1.25626, 1.284254, 1.3880290000000002]

weighted_val_loss4=[0.475354, 0.690083, 0.727412, 0.551563, 0.5307430000000001, 0.729244, 0.593829, 0.96916, 
                    1.0226, 1.0310709999999998, 1.0819729999999999, 1.1858469999999999, 1.198477, 1.140343, 1.262689]

weighted_val_loss5=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 
                    0.773781, 0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694,
                    1.010774, 1.0873469999999998, 1.116158]

# %%
val_loss1=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 
           0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 
           1.116158]

val_loss2=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 
           0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 
           1.116158]

val_loss3=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 
           0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 
           1.116158]

val_loss4=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 
           0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 
           1.116158]

val_loss5=[0.412951, 0.597958, 0.523389, 0.559671, 0.44275, 0.6874560000000001, 0.655201, 0.773781, 
           0.9161590000000001, 0.8782639999999999, 1.0031780000000001, 1.003694, 1.010774, 1.0873469999999998, 
           1.116158]

# %%
plt.plot(weighted_val_loss1, label='Fraction of Positive class samples=0.1')
plt.plot(weighted_val_loss2, label='Fraction of Positive class samples=0.25')
plt.plot(weighted_val_loss3, label='Fraction of Positive class samples=0.5')
plt.plot(weighted_val_loss4, label='Fraction of Positive class samples=0.75')
plt.plot(weighted_val_loss5, label='Fraction of Positive class samples=1')
plt.legend()

# %%
weighted_acc1=[0.8761469999999999, 0.87844, 0.893349, 0.8910549999999999, 0.91055, 0.8704129999999999, 
               0.9002290000000001, 0.896789, 0.899083, 0.883028, 0.888761, 0.8910549999999999, 0.9002290000000001, 
               0.896789, 0.896789]

weighted_acc2=[0.8681190000000001, 0.856651, 0.8681190000000001, 0.883028, 0.892202, 0.87156, 0.902523, 
               0.886468, 0.8761469999999999, 0.869266, 0.866972, 0.8795870000000001, 0.8738530000000001, 
               0.888761, 0.880734]

weighted_acc3=[0.8738530000000001, 0.8520639999999999, 0.8761469999999999, 0.8818809999999999, 0.902523, 
               0.872706, 0.895642, 0.896789, 0.877294, 0.875, 0.880734, 0.889908, 0.8853209999999999, 0.886468, 
               0.883028]

weighted_acc4=[0.866972, 0.8486239999999999, 0.8486239999999999, 0.893349, 0.9002290000000001,
               0.8818809999999999, 0.9013760000000001, 0.8795870000000001, 0.8818809999999999, 0.886468, 
               0.877294, 0.8795870000000001, 0.87844, 0.888761, 0.880734]

weighted_acc5=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
               0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 
               0.8818809999999999]

# %%
acc1=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
      0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

acc2=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
      0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

acc3=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
      0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

acc4=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
      0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

acc5=[0.8704129999999999, 0.853211, 0.860092, 0.883028, 0.895642, 0.87844, 0.895642, 0.888761, 
      0.8795870000000001, 0.8979360000000001, 0.883028, 0.888761, 0.888761, 0.8853209999999999, 0.8818809999999999]

# %%
plt.plot(weighted_acc1, label='Fraction of Positive class samples=0.1')
plt.plot(weighted_acc2, label='Fraction of Positive class samples=0.25')
plt.plot(weighted_acc3, label='Fraction of Positive class samples=0.5')
plt.plot(weighted_acc4, label='Fraction of Positive class samples=0.75')
plt.plot(weighted_acc5, label='Fraction of Positive class samples=1')
plt.legend()

# %%
weighted_accs = [weighted_acc1,weighted_acc2,weighted_acc3,weighted_acc4,weighted_acc5]
accs = [acc1,acc2,acc3,acc4,acc5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_accs[i], label='Weighted')
    axes[i].plot(accs[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
weighted_val_loss = [weighted_val_loss1,weighted_val_loss2,weighted_val_loss3,weighted_val_loss4,weighted_val_loss5]
val_loss = [val_loss1,val_loss2,val_loss3,val_loss4,val_loss5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_val_loss[i], label='Weighted')
    axes[i].plot(val_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)

plt.show()

# %%
weighted_train_loss = [weighted_train_loss1,weighted_train_loss2,weighted_train_loss3,weighted_train_loss4,weighted_train_loss5]
train_loss = [train_loss1,train_loss2,train_loss3,train_loss4,train_loss5]
titles = ["Fraction of Positive class samples is 0.1","Fraction of Positive class samples is 0.25",
          "Fraction of Positive class samples is 0.5","Fraction of Positive class samples is 0.75",
          "Fraction of Positive class samples is 1"]

fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_train_loss[i], label='Weighted')
    axes[i].plot(train_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))

ax[0].plot(weighted_acc1, label='Fraction of Positive class samples is=0.1')
ax[0].plot(weighted_acc2, label='Fraction of Positive class samples is=0.25')
ax[0].plot(weighted_acc3, label='Fraction of Positive class samples is=0.5')
ax[0].plot(weighted_acc4, label='Fraction of Positive class samples is=0.75')
ax[0].plot(weighted_acc5, label='Fraction of Positive class samples is=1')
ax[0].plot(acc5, label='Non Weighted')
ax[0].set_title("Weighted")
ax[0].legend()


ax[1].plot(acc1, label='Fraction of Positive class samples is=0.1')
ax[1].plot(acc2, label='Fraction of Positive class samples is=0.25')
ax[1].plot(acc3, label='Fraction of Positive class samples is=0.5')
ax[1].plot(acc4, label='Fraction of Positive class samples is=0.75')
ax[1].plot(acc5, label='Fraction of Positive class samples is=1')
ax[1].set_title("Non Weighted")
ax[1].legend()

plt.show()
