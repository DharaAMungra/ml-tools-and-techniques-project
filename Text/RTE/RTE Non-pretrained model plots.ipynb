# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('val.csv',sep='\t')
print(df['Training Loss'].to_list())
print(df['Validation Loss'].to_list())
print(df['Acc'].to_list())
# Out:
# [0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 0.4064, 0.3311, 0.3307, 0.2821, 0.2842]
# [0.8622709999999999, 0.7682640000000001, 0.741244, 0.722118, 0.735004, 0.693059, 0.8498379999999999, 0.780382, 0.9310229999999999, 0.928974, 0.976883, 1.129032, 1.187476, 1.272748, 1.191025]
# [0.527076, 0.527076, 0.527076, 0.527076, 0.519856, 0.537906, 0.519856, 0.559567, 0.530686, 0.527076, 0.552347, 0.5559569999999999, 0.566787, 0.552347, 0.559567]

# %%
weighted_train_loss1=[0.4802,0.4786,0.4695,0.4695,0.4722,0.4717,0.4518,0.4611,0.3922,0.364,0.3763,
                      0.2905,0.2497,0.2421,0.2288]

weighted_train_loss2=[0.6607, 0.6599, 0.65, 0.6468, 0.6541, 0.6418, 0.6337, 0.5958, 0.5256, 
                      0.4809, 0.4397, 0.3629, 0.3352, 0.3078, 0.2898]

weighted_train_loss3=[0.7118, 0.7067, 0.7039, 0.6949, 0.7046, 0.6782, 0.671, 0.6605, 0.5476, 0.4801, 
                      0.4604, 0.3914, 0.345, 0.3103, 0.3026]

weighted_train_loss4=[0.6872, 0.6832, 0.6844, 0.6732, 0.6857, 0.6559, 0.6418, 0.5587, 0.494, 0.4546, 
                      0.4112, 0.3541, 0.3296, 0.2967, 0.2882]

weighted_train_loss5=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 
                      0.4972, 0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

# %%
train_loss1=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 
             0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

train_loss2=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 
             0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

train_loss3=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 
             0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

train_loss4=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 
             0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

train_loss5=[0.6491, 0.6431, 0.6513, 0.6367, 0.6488, 0.6189, 0.6156, 0.5438, 0.4968, 0.4972, 
             0.4064, 0.3311, 0.3307, 0.2821, 0.2842]

# %%
plt.plot(weighted_train_loss1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_train_loss2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_train_loss3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_train_loss4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_train_loss5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_val_loss1=[0.384969,0.367571,0.339333,0.343571,0.345816,0.332142,0.334457,0.435886,0.457539,
                    0.805197,0.567439,0.756421,0.762934,1.217288,0.841306]

weighted_val_loss2=[0.6480060000000001, 0.589468, 0.545528, 0.5494479999999999, 0.560168, 0.5272359999999999, 
                    0.5352439999999999, 0.714726, 0.764575, 
                    0.783615, 0.847226, 0.9753280000000001, 1.0491709999999999, 1.384468, 1.096292]

weighted_val_loss3=[0.792534, 0.7316729999999999, 0.683183, 0.674363, 0.693613, 0.654412, 0.661799, 0.864798, 
                    0.915106, 0.960996, 0.9799979999999999, 1.1794360000000002, 1.184603, 1.413606, 1.2345270000000002]

weighted_val_loss4=[0.8723479999999999, 0.7670560000000001, 0.7264609999999999, 0.719567, 0.736455, 0.69058, 
                    0.7553270000000001, 1.091507, 0.8955350000000001, 1.003952, 1.131005, 1.076065, 1.12266, 
                    1.3598700000000001, 1.285244]

weighted_val_loss5=[0.8622709999999999, 0.7682640000000001, 0.741244, 0.722118, 0.735004, 0.693059,
.552347, 0.5559569999999999, 0.566787, 0.552347, 0.559567]

acc5=[0.527076, 0.527076, 0.527076, 0.527076, 0.519856, 0.537906, 0.519856, 0.559567, 0.530686, 0.527076, 
      0.552347, 0.5559569999999999, 0.566787, 0.552347, 0.559567]

# %%
plt.plot(weighted_acc1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_acc2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_acc3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_acc4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_acc5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_accs = [weighted_acc1,weighted_acc2,weighted_acc3,weighted_acc4,weighted_acc5]
accs = [acc1,acc2,acc3,acc4,acc5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_accs[i], label='Weighted')
    axes[i].plot(accs[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
weighted_val_loss = [weighted_val_loss1,weighted_val_loss2,weighted_val_loss3,weighted_val_loss4,weighted_val_loss5]
val_loss = [val_loss1,val_loss2,val_loss3,val_loss4,val_loss5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_val_loss[i], label='Weighted')
    axes[i].plot(val_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)

plt.show()

# %%
weighted_train_loss = [weighted_train_loss1,weighted_train_loss2,weighted_train_loss3,weighted_train_loss4,weighted_train_loss5]
train_loss = [train_loss1,train_loss2,train_loss3,train_loss4,train_loss5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]

fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_train_loss[i], label='Weighted')
    axes[i].plot(train_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))

ax[0].plot(weighted_acc1, label='Fraction of Non-entailment=0.1')
ax[0].plot(weighted_acc2, label='Fraction of Non-entailment=0.25')
ax[0].plot(weighted_acc3, label='Fraction of Non-entailment=0.5')
ax[0].plot(weighted_acc4, label='Fraction of Non-entailment=0.75')
ax[0].plot(weighted_acc5, label='Fraction of Non-entailment=1')
ax[0].plot(acc5, label='Non Weighted')
ax[0].set_title("Weighted")
ax[0].legend()


ax[1].plot(acc1, label='Fraction of Non-entailment=0.1')
ax[1].plot(acc2, label='Fraction of Non-entailment=0.25')
ax[1].plot(acc3, label='Fraction of Non-entailment=0.5')
ax[1].plot(acc4, label='Fraction of Non-entailment=0.75')
ax[1].plot(acc5, label='Fraction of Non-entailment=1')
ax[1].set_title("Non Weighted")
ax[1].legend()

plt.show()
