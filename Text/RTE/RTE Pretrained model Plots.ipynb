# %%
import matplotlib.pyplot as plt

# %%
weighted_train_loss1=[0.5527,0.4503,0.4051,0.3425,0.2617,0.1625,0.1236,0.1004,0.0699,0.061,0.0529,0.0334,0.0292,0.0263,0.0279]

weighted_train_loss2=[0.6703,0.6074,0.5449,0.4654,0.3512,0.2054,0.159,0.1193,0.0765,0.058,0.055,0.031,0.031,0.0231,0.0308]

weighted_train_loss3=[0.7025,0.6476,0.5871,0.5055,0.3884,0.2362,0.1906,0.1501,0.1039,0.0883,0.0769,0.034,0.035,0.0243,0.0271]

weighted_train_loss4=[0.6818,0.6248,0.5726,0.491,0.3841,0.2292,0.191,0.1517,0.1112,0.087,0.0861,0.0532,0.0376,0.0457,0.0331]

weighted_train_loss5=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

# %%
train_loss1=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

train_loss2=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

train_loss3=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

train_loss4=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

train_loss5=[0.6496,0.589,0.5438,0.4638,0.3675,0.2206,0.1804,0.1446,0.1065,0.0936,0.0838,0.0538,0.0456,0.0446,0.0379]

# %%
plt.plot(weighted_train_loss1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_train_loss2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_train_loss3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_train_loss4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_train_loss5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_val_loss1=[0.367333,0.33495,0.398969,0.506724,0.558075,0.750224,0.828695,
           0.962463,1.120447,1.284714,1.402498,1.467992,1.617808,1.609813,1.590827]

weighted_val_loss2=[0.564893,0.54394,0.59755,0.657721,0.73579,0.860927,0.818332,1.167462,1.252027,1.390512,1.564643,1.723895,
           1.804472,1.841141,1.864574]

weighted_val_loss3=[0.690202,0.676017,0.694391,0.732776,0.823667,0.937005,0.958401,1.184606,1.178029,1.311075,1.641652,
           1.666233,1.826089,1.900326,1.901935]

weighted_val_loss4=[0.726977,0.712586,0.706739,0.761384,0.839095,0.938746,0.987098,1.207218,1.310975,1.300988,1.514169,
           1.578493,1.636385,1.693952,1.694846]

weighted_val_loss5=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,1.392153,1.461906,
           1.512114,1.561542,1.557431]

# %%
val_loss1=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,
           1.392153,1.461906,1.512114,1.561542,1.557431]

val_loss2=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,
           1.392153,1.461906,1.512114,1.561542,1.557431]

val_loss3=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,1.392153,
           1.461906,1.512114,1.561542,1.557431]

val_loss4=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,
           1.392153,1.461906,1.512114,1.561542,1.557431]

val_loss5=[0.725813,0.715586,0.704,0.756826,0.848482,0.902078,1.02541,1.170527,1.25046,1.253942,
           1.392153,1.461906,1.512114,1.561542,1.557431]

# %%
plt.plot(weighted_val_loss1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_val_loss2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_val_loss3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_val_loss4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_val_loss5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_acc1=[0.472924,0.472924,0.501805,0.638989,0.66426,0.642599,0.635379,0.649819,0.646209,0.638989,0.635379,
      0.638989,0.635379,0.646209,0.646209]

weighted_acc2=[0.472924,0.519856,0.606498,0.646209,0.649819,0.635379,0.66065,0.642599,0.642599,0.646209,0.642599,
      0.642599,0.642599,0.642599,0.642599]

weighted_acc3=[0.555957,0.610108,0.620939,0.631769,0.631769,0.624549,0.638989,0.628159,0.65704,0.66065,0.635379,
      0.642599,0.646209,0.649819,0.65343]

weighted_acc4=[0.563177,0.592058,0.620939,0.642599,0.642599,0.638989,0.631769,0.617329,0.65343,0.646209,0.649819,
      0.65704,0.65343,0.65343,0.65343]

weighted_acc5=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,0.649819,0.65343,
      0.646209,0.65343,0.65343]

# %%
acc1=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,
      0.649819,0.65343,0.646209,0.65343,0.65343]

acc2=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,
      0.649819,0.65343,0.646209,0.65343,0.65343]

acc3=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,
      0.649819,0.65343,0.646209,0.65343,0.65343]

acc4=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,
      0.649819,0.65343,0.646209,0.65343,0.65343]

acc5=[0.552347,0.577617,0.638989,0.635379,0.638989,0.631769,0.635379,0.624549,0.638989,0.642599,
      0.649819,0.65343,0.646209,0.65343,0.65343]

# %%
plt.plot(weighted_acc1, label='Fraction of Non-entailment=0.1')
plt.plot(weighted_acc2, label='Fraction of Non-entailment=0.25')
plt.plot(weighted_acc3, label='Fraction of Non-entailment=0.5')
plt.plot(weighted_acc4, label='Fraction of Non-entailment=0.75')
plt.plot(weighted_acc5, label='Fraction of Non-entailment=1')
plt.legend()

# %%
weighted_accs = [weighted_acc1,weighted_acc2,weighted_acc3,weighted_acc4,weighted_acc5]
accs = [acc1,acc2,acc3,acc4,acc5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]

# %%
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_accs[i], label='Weighted')
    axes[i].plot(accs[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
weighted_val_loss = [weighted_val_loss1,weighted_val_loss2,weighted_val_loss3,weighted_val_loss4,weighted_val_loss5]
val_loss = [val_loss1,val_loss2,val_loss3,val_loss4,val_loss5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]

# %%
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_val_loss[i], label='Weighted')
    axes[i].plot(val_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)

plt.show()

# %%
weighted_train_loss = [weighted_train_loss1,weighted_train_loss2,weighted_train_loss3,weighted_train_loss4,weighted_train_loss5]
train_loss = [train_loss1,train_loss2,train_loss3,train_loss4,train_loss5]
titles = ["Fraction of Non-entailment samples is 0.1","Fraction of Non-entailment samples is 0.25",
          "Fraction of Non-entailment samples is 0.5","Fraction of Non-entailment samples is 0.75",
          "Fraction of Non-entailment samples is 1"]

# %%
fig,ax = plt.subplots(2,3,figsize=(15,10))

axes = ax.ravel()
for i in range(5):
    axes[i].plot(weighted_train_loss[i], label='Weighted')
    axes[i].plot(train_loss[i], label='Non-weighted')
    axes[i].set_title(titles[i])
    axes[i].legend()

axes[5].set_visible(False)
    
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))

ax[0].plot(weighted_acc1, label='Fraction of Non-entailment=0.1')
ax[0].plot(weighted_acc2, label='Fraction of Non-entailment=0.25')
ax[0].plot(weighted_acc3, label='Fraction of Non-entailment=0.5')
ax[0].plot(weighted_acc4, label='Fraction of Non-entailment=0.75')
ax[0].plot(weighted_acc5, label='Fraction of Non-entailment=1')
ax[0].plot(acc5, label='Non Weighted')
ax[0].set_title("Weighted")
ax[0].legend()


ax[1].plot(acc1, label='Fraction of Non-entailment=0.1')
ax[1].plot(acc2, label='Fraction of Non-entailment=0.25')
ax[1].plot(acc3, label='Fraction of Non-entailment=0.5')
ax[1].plot(acc4, label='Fraction of Non-entailment=0.75')
ax[1].plot(acc5, label='Fraction of Non-entailment=1')
ax[1].set_title("Non Weighted")
ax[1].legend()

plt.show()
